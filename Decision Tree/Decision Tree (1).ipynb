# %%
import pandas as pd
import math

# %%
df[df['Breathing issues']=='YES']
# Out:
#    Fever Cough Breathing issues Infected
# ID
# 2    YES   YES              YES      YES
# 4    YES    NO              YES      YES
# 5    YES   YES              YES      YES
# 7    YES    NO              YES      YES
# 8    YES    NO              YES      YES
# 9     NO   YES              YES      YES
# 12    NO   YES              YES      YES
# 13    NO   YES              YES       NO

# %%
class decision:
    def __init__(self):
        self.left = None
        self.right = None
        self.data = None
    
    def ig(self,i,S,df):
        df1 = df[df[i]=='YES']
        df2 = df[df[i]=='NO']
        n1=df1[df1[target]=='YES'].shape[0]
        n2=df1[df1[target]=='NO'].shape[0]
        if n1 and n2:
            s1 = -1*(n1/(df1.shape[0]))*math.log2((n1/(df1.shape[0])))-1*(n2/(df1.shape[0]))*math.log2((n2/(df1.shape[0])))
        else:
            s1=0
        n1=df2[df2[target]=='YES'].shape[0]
        n2=df2[df2[target]=='NO'].shape[0]
        if n1 and n2:
            s2 = -1*(n1/(df2.shape[0]))*math.log2((n1/df2.shape[0]))-1*(n2/(df2.shape[0]))*math.log2((n2/(df2.shape[0])))
        else:
            s2=0
        return S-(df1.shape[0]/df.shape[0])*s1-(df2.shape[0]/df.shape[0])*s2
   
    def selectnode(self,df):
        print(df)
        col=list(df.columns)
        target = col.pop()
#         print(target)
        n1=df[df[target]=='YES'].shape[0]
        n2=df[df[target]=='NO'].shape[0]
        if n1 and n2:
            S = -1*(n1/(df.shape[0]))*math.log2((n1/(df.shape[0])))-1*(n2/(df.shape[0]))*math.log2((n2/(df.shape[0])))
            IG=[]
            for i in col:
                if i not in visited:
                    s=self.ig(i,S,df)
                    IG.append(round(s,2))
                else:
                    IG.append(0)
#             print(IG)
            self.data= col[IG.index(max(IG))]
            print(self.data)
            visited.append(self.data)
            n1=df[df[self.data]=='YES'].shape[0]
            print(n1)
            if n1 == df.shape[0]:
                visited.append('Infectedl')
                return 'Infectedl'
            elif n1:
                self.left=self.selectnode(df[df[self.data]=='YES'])
                
            n2=df[df[self.data]=='NO'].shape[0]
            print(n2)
            
            if n2==df.shape[0]:
                visited.append('Not infectedr')
                return 'Not Infectedr'
            elif n2:
                self.right=self.selectnode(df[df[self.data]=='NO'])
#             else:
#                 visited.append('Not Infected')
#                 return 'Not Infected'
        elif n2==0:
            visited.append('Infectedl')
            return 'Infectedl'
        else:
            visited.append('Not Infectedr')
            return 'Not Infectedr'

# %%
df = pd.read_csv('sample dataset of COVID-19.csv')
df.set_index('ID',inplace=True)
col = list(df.columns)
# target=col.pop()
# S = -1*((df[df['Infected']=='YES'].shape[0])/(df.shape[0]))*math.log2(((df[df['Infected']=='YES'].shape[0])/(df.shape[0])))-1*((df[df['Infected']=='NO'].shape[0])/(df.shape[0]))*math.log2(((df[df['Infected']=='NO'].shape[0])/(df.shape[0])))
visited=[]
root = decision()
root.selectnode(df)
# Out:
#    Fever Cough Breathing issues Infected
# ID
# 1     NO    NO               NO       NO
# 2    YES   YES              YES      YES
# 3    YES   YES               NO       NO
# 4    YES    NO              YES      YES
# 5    YES   YES              YES      YES
# 6     NO   YES               NO       NO
# 7    YES    NO              YES      YES
# 8    YES    NO              YES      YES
# 9     NO   YES              YES      YES
# 10   YES   YES               NO      YES
# 11    NO   YES               NO       NO
# 12    NO   YES              YES      YES
# 13    NO   YES              YES       NO
# 14   YES   YES               NO       NO
# Breathing issues
# 8
#    Fever Cough Breathing issues Infected
# ID
# 2    YES   YES              YES      YES
# 4    YES    NO              YES      YES
# 5    YES   YES              YES      YES
# 7    YES    NO              YES      YES
# 8    YES    NO              YES      YES
# 9     NO   YES              YES      YES
# 12    NO   YES              YES      YES
# 13    NO   YES              YES       NO
# Fever
# 5
#    Fever Cough Breathing issues Infected
# ID
# 2    YES   YES              YES      YES
# 4    YES    NO              YES      YES
# 5    YES   YES              YES      YES
# 7    YES    NO              YES      YES
# 8    YES    NO              YES      YES
# 3
#    Fever Cough Breathing issues Infected
# ID
# 9     NO   YES              YES      YES
# 12    NO   YES              YES      YES
# 13    NO   YES              YES       NO
# Fever
# 0
# 3
# 6
#    Fever Cough Breathing issues Infected
# ID
# 1     NO    NO               NO       NO
# 6     NO   YES               NO       NO
# 9     NO   YES              YES      YES
# 11    NO   YES               NO       NO
# 12    NO   YES              YES      YES
# 13    NO   YES              YES       NO
# Cough
# 5
#    Fever Cough Breathing issues Infected
# ID
# 6     NO   YES               NO       NO
# 9     NO   YES              YES      YES
# 11    NO   YES               NO       NO
# 12    NO   YES              YES      YES
# 13    NO   YES              YES       NO
# Fever
# 0
# 5
# 6

# %%
visited
# Out:
# ['Breathing issues',
#  'Fever',
#  'Infectedl',
#  'Fever',
#  'Not infectedr',
#  'Cough',
#  'Fever',
#  'Not infectedr',
#  'Not infectedr']
